# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

import rdflib
from rdflib import Graph, Literal, Namespace, RDF, URIRef, OWL
from rdflib.extras.external_graph_libs import rdflib_to_networkx_digraph
from rdflib.namespace import DC, FOAF

from owlready2 import *
from owlready2 import get_ontology

from sklearn.model_selection import train_test_split

import networkx as nx
import networkx.algorithms.community as nx_comm

from sklearn.decomposition import PCA
import seaborn as sns
from adjustText import adjust_text
# %matplotlib inline

random.seed(10)
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation

# %% [markdown]
# Loading the data with necessary columns

# %%
data = pd.read_excel('opioid_data_merged_min.xlsx')

# %%
data
# Out:
#      WorldwideUniqueCaseIdentification     sex                  Outcome  \
# 0        NL-002147023-NVSC2020NL143475  female  Recovered with sequelae
# 1        NL-002147023-NVSC2020NL143475  female  Recovered with sequelae
# 2        NL-002147023-NVSC2020NL223553  female                Recovered
# 3        NL-002147023-NVSC2020NL223553  female                Recovered
# 4        NL-002147023-NVSC2020NL223553  female                Recovered
# ...                                ...     ...                      ...
# 6192                 NL-TEVA-719924ROM    male                Recovered
# 6193                 NL-TEVA-719924ROM    male                Recovered
# 6194                 NL-TEVA-719924ROM    male                Recovered
# 6195                 NL-TEVA-719924ROM    male                Recovered
# 6196                 NL-TEVA-719924ROM    male                Recovered
#
#        ATCode    PTCode  Frequency     age_group weight_group  is_sideeffect
# 0     N02AX02  10012218        0.1  (64.0, 90.0]   overweight           True
# 1     N02AX02  10075611        0.0  (64.0, 90.0]   overweight          False
# 2     N02AX02  10076493        0.0  (64.0, 90.0]   overweight          False
# 3     N02AX02  10009839        0.0  (64.0, 90.0]   overweight          False
# 4     N02AX02  10009839        0.0  (64.0, 90.0]   overweight          False
# ...       ...       ...        ...           ...          ...            ...
# 6192  N02AA05  10037660        0.0  (64.0, 90.0]       normal          False
# 6193  N02AA05  10062352        0.0  (64.0, 90.0]       normal          False
# 6194  N02AA05  10006002        0.0  (64.0, 90.0]       normal          False
# 6195  N02AA05  10046571        0.0  (64.0, 90.0]       normal          False
# 6196  N02AA05  10062352        0.0  (64.0, 90.0]       normal          False
#
# [6197 rows x 9 columns]

# %% [markdown]
# Some transformations

# %%
data['WorldwideUniqueCaseIdentification'] = data.WorldwideUniqueCaseIdentification.astype(str)
data['age_group'] = data.age_group.astype(str)
data['PTCode'] = data.PTCode.astype(str)

# %% [markdown]
# Triple extraction

# %%
triples = []
for _, row in data.iterrows():
        
    # Weight group info
    weight_group = (row['WorldwideUniqueCaseIdentification'], "hasWeightGroup", row['weight_group'])

    # Age group info
    age_group = (row['WorldwideUniqueCaseIdentification'], "hasAgeGroup", row['age_group'])

    # Gender info
    sex = (row['WorldwideUniqueCaseIdentification'], "hasGender", row['sex'])

    #Outcome
    outcome = (row['WorldwideUniqueCaseIdentification'], "hasOutcome", row['Outcome'])

    #Symptom
    symptom = (row['WorldwideUniqueCaseIdentification'], "hasSymptom", row['PTCode'])

    #Drug
    drug = (row['WorldwideUniqueCaseIdentification'], "isGivenDrug", row['ATCode'])

    #Frequency
    frequency = (row['PTCode'], "hasFrequency", row['Frequency'])    
    
    #Side effect
    if row['is_sideeffect'] == True:
        side_effect = (row['WorldwideUniqueCaseIdentification'], "hasSideEffect", row['PTCode'])
    else:
        side_effect = (row['WorldwideUniqueCaseIdentification'], "hasSideEffect", "None")

    triples.extend((weight_group, age_group, sex, outcome, symptom, drug, frequency, side_effect))

# %% [markdown]
# This is how they look in a dataframe:

# %%
triples_df = pd.DataFrame(triples, columns=["subject", "predicate", "object"])
triples_df = triples_df.drop_duplicates()
triples_df[(triples_df.subject=="NL-TEVA-719924ROM")]
# Out:
#                  subject       predicate        object
# 49520  NL-TEVA-719924ROM  hasWeightGroup        normal
# 49521  NL-TEVA-719924ROM     hasAgeGroup  (64.0, 90.0]
# 49522  NL-TEVA-719924ROM       hasGender          male
# 49523  NL-TEVA-719924ROM      hasOutcome     Recovered
# 49524  NL-TEVA-719924ROM      hasSymptom      10046571
# 49525  NL-TEVA-719924ROM     isGivenDrug       N02AA05
# 49527  NL-TEVA-719924ROM   hasSideEffect          None
# 49532  NL-TEVA-719924ROM      hasSymptom      10047700
# 49540  NL-TEVA-719924ROM      hasSymptom      10037660
# 49548  NL-TEVA-719924ROM      hasSymptom      10062352
# 49556  NL-TEVA-719924ROM      hasSymptom      10006002

# %% [markdown]
# Train-test split

# %%
from ampligraph.evaluation import train_test_split_no_unseen

X_train, X_test = train_test_split_no_unseen(np.array(triples), test_size=7930)

# %%
print('Train set size: ', X_train.shape)
print('Test set size: ', X_test.shape)
# Out:
# Train set size:  (41646, 3)
# Test set size:  (7930, 3)

# %% [markdown]
# We choose ComplEx as our Knowledge Graph Embedding model:

# %%
from ampligraph.latent_features.models import ScoringBasedEmbeddingModel
    
# Initialize a ComplEx neural embedding model: the embedding size is k,
# eta specifies the number of corruptions to generate per each positive,
# scoring_type determines the scoring function of the embedding model.
model = ScoringBasedEmbeddingModel(k=150,
                                   eta=10,
                                   scoring_type='ComplEx')

# %% [markdown]
# Compile model

# %%
import tensorflow as tf

from ampligraph.latent_features.loss_functions import get as get_loss
from ampligraph.latent_features.regularizers import get as get_regularizer

# Optimizer, loss and regularizer definition
optim = tf.keras.optimizers.Adam(learning_rate=1e-3)
loss = get_loss('pairwise', {'margin': 0.5})
regularizer = get_regularizer('LP', {'p': 2, 'lambda': 1e-5})

# Compilation of the model
model.compile(loss=loss,
              optimizer='adam',
              entity_relation_regularizer=regularizer,
              entity_relation_initializer='glorot_uniform')

# %% [markdown]
# Train model

# %%
# Fit the model on training and validation set

model.fit(X_train,
          batch_size=int(X_train.shape[0] / 10), # use 1/10 of the training set as batch size
          epochs=200,                    # Number of training epochs
          verbose=True                  # Enable stdout messages
          )
# Out:
# Epoch 1/200
# 12/12 [==============================] - 9s 714ms/step - loss: 18898.6113
# Epoch 2/200
# 12/12 [==============================] - 4s 327ms/step - loss: 18829.7910
# Epoch 3/200
# 12/12 [==============================] - 4s 332ms/step - loss: 18720.4707
# Epoch 4/200
# 12/12 [==============================] - 4s 329ms/step - loss: 18535.0352
# Epoch 5/200
# 12/12 [==============================] - 4s 323ms/step - loss: 18224.8418
# Epoch 6/200
# 12/12 [==============================] - 4s 328ms/step - loss: 17724.5703
# Epoch 7/200
# 12/12 [==============================] - 4s 319ms/step - loss: 16956.4648
# Epoch 8/200
# 12/12 [==============================] - 4s 320ms/step - loss: 15937.3945
# Epoch 9/200
# 12/12 [==============================] - 4s 323ms/step - loss: 14863.9600
# Epoch 10/200
# 12/12 [==============================] - 4s 327ms/step - loss: 13870.2158
# Epoch 11/200
# 12/12 [==============================] - 4s 332ms/step - loss: 12984.0059
# Epoch 12/200
# 12/12 [==============================] - 4s 325ms/step - loss: 12198.3174
# Epoch 13/200
# 12/12 [==============================] - 4s 323ms/step - loss: 11500.3281
# Epoch 14/200
# 12/12 [==============================] - 4s 320ms/step - loss: 10880.5693
# Epoch 15/200
# 12/12 [==============================] - 4s 318ms/step - loss: 10325.6602
# Epoch 16/200
# 12/12 [==============================] - 4s 321ms/step - loss: 9827.2002
# Epoch 17/200
# 12/12 [==============================] - 4s 311ms/step - loss: 9377.1689
# Epoch 18/200
# 12/12 [==============================] - 4s 325ms/step - loss: 8969.9941
# Epoch 19/200
# 12/12 [==============================] - 3s 292ms/step - loss: 8598.5596
# Epoch 20/200
# 12/12 [==============================] - 4s 322ms/step - loss: 8259.6211
# Epoch 21/200
# 12/12 [==============================] - 4s 312ms/step - loss: 7950.1401
# Epoch 22/200
# 12/12 [==============================] - 4s 314ms/step - loss: 7664.5156
# Epoch 23/200
# 12/12 [==============================] - 4s 309ms/step - loss: 7401.2412
# Epoch 24/200
# 12/12 [==============================] - 4s 296ms/step - loss: 7158.7705
# Epoch 25/200
# 12/12 [==============================] - 4s 315ms/step - loss: 6933.9507
# Epoch 26/200
# 12/12 [==============================] - 4s 298ms/step - loss: 6725.0659
# Epoch 27/200
# 12/12 [==============================] - 4s 311ms/step - loss: 6530.5444
# Epoch 28/200
# 12/12 [==============================] - 4s 306ms/step - loss: 6348.4580
# Epoch 29/200
# 12/12 [==============================] - 4s 295ms/step - loss: 6178.1772
# Epoch 30/200
# 12/12 [==============================] - 4s 317ms/step - loss: 6018.5264
# Epoch 31/200
# 12/12 [==============================] - 4s 318ms/step - loss: 5869.1963
# Epoch 32/200
# 12/12 [==============================] - 4s 314ms/step - loss: 5728.3472
# Epoch 33/200
# 12/12 [==============================] - 4s 318ms/step - loss: 5595.2578
# Epoch 34/200
# 12/12 [==============================] - 4s 312ms/step - loss: 5470.0972
# Epoch 35/200
# 12/12 [==============================] - 4s 323ms/step - loss: 5351.5645
# Epoch 36/200
# 12/12 [==============================] - 4s 318ms/step - loss: 5239.4717
# Epoch 37/200
# 12/12 [==============================] - 4s 316ms/step - loss: 5133.1436
# Epoch 38/200
# 12/12 [==============================] - 4s 313ms/step - loss: 5032.3198
# Epoch 39/200
# 12/12 [==============================] - 4s 334ms/step - loss: 4936.2402
# Epoch 40/200
# 12/12 [==============================] - 4s 300ms/step - loss: 4845.2671
# Epoch 41/200
# 12/12 [==============================] - 4s 303ms/step - loss: 4758.5166
# Epoch 42/200
# 12/12 [==============================] - 4s 311ms/step - loss: 4675.5249
# Epoch 43/200
# 12/12 [==============================] - 3s 279ms/step - loss: 4596.4238
# Epoch 44/200
# 12/12 [==============================] - 3s 289ms/step - loss: 4520.8179
# Epoch 45/200
# 12/12 [==============================] - 4s 293ms/step - loss: 4448.3218
# Epoch 46/200
# 12/12 [==============================] - 4s 310ms/step - loss: 4379.2275
# Epoch 47/200
# 12/12 [==============================] - 4s 308ms/step - loss: 4312.8833
# Epoch 48/200
# 12/12 [==============================] - 4s 343ms/step - loss: 4249.1787
# Epoch 49/200
# 12/12 [==============================] - 4s 330ms/step - loss: 4188.0215
# Epoch 50/200
# 12/12 [==============================] - 4s 305ms/step - loss: 4129.3955
# Epoch 51/200
# 12/12 [==============================] - 4s 309ms/step - loss: 4072.6748
# Epoch 52/200
# 12/12 [==============================] - 4s 310ms/step - loss: 4018.4739
# Epoch 53/200
# 12/12 [==============================] - 4s 308ms/step - loss: 3966.0103
# Epoch 54/200
# 12/12 [==============================] - 4s 308ms/step - loss: 3915.6023
# Epoch 55/200
# 12/12 [==============================] - 4s 307ms/step - loss: 3866.7703
# Epoch 56/200
# 12/12 [==============================] - 4s 303ms/step - loss: 3819.7500
# Epoch 57/200
# 12/12 [==============================] - 4s 307ms/step - loss: 3774.4402
# Epoch 58/200
# 12/12 [==============================] - 4s 307ms/step - loss: 3730.6794
# Epoch 59/200
# 12/12 [==============================] - 4s 314ms/step - loss: 3688.4741
# Epoch 60/200
# 12/12 [==============================] - 4s 308ms/step - loss: 3647.3916
# Epoch 61/200
# 12/12 [==============================] - 4s 308ms/step - loss: 3607.6140
# Epoch 62/200
# 12/12 [==============================] - 4s 306ms/step - loss: 3569.1238
# Epoch 63/200
# 12/12 [==============================] - 4s 310ms/step - loss: 3531.9851
# Epoch 64/200
# 12/12 [==============================] - 4s 308ms/step - loss: 3495.9851
# Epoch 65/200
# 12/12 [==============================] - 4s 304ms/step - loss: 3460.9290
# Epoch 66/200
# 12/12 [==============================] - 4s 319ms/step - loss: 3427.1953
# Epoch 67/200
# 12/12 [==============================] - 4s 308ms/step - loss: 3394.2781
# Epoch 68/200
# 12/12 [==============================] - 4s 303ms/step - loss: 3362.2710
# Epoch 69/200
# 12/12 [==============================] - 4s 307ms/step - loss: 3331.3975
# Epoch 70/200
# 12/12 [==============================] - 4s 309ms/step - loss: 3301.2759
# Epoch 71/200
# 12/12 [==============================] - 3s 289ms/step - loss: 3271.8589
# Epoch 72/200
# 12/12 [==============================] - 4s 299ms/step - loss: 3243.3997
# Epoch 73/200
# 12/12 [==============================] - 4s 303ms/step - loss: 3215.9238
# Epoch 74/200
# 12/12 [==============================] - 4s 301ms/step - loss: 3189.0227
# Epoch 75/200
# 12/12 [==============================] - 4s 311ms/step - loss: 3162.7261
# Epoch 76/200
# 12/12 [==============================] - 4s 301ms/step - loss: 3136.9045
# Epoch 77/200
# 12/12 [==============================] - 4s 312ms/step - loss: 3111.8936
# Epoch 78/200
# 12/12 [==============================] - 4s 307ms/step - loss: 3087.5872
# Epoch 79/200
# 12/12 [==============================] - 4s 306ms/step - loss: 3063.8979
# Epoch 80/200
# 12/12 [==============================] - 4s 308ms/step - loss: 3040.8193
# Epoch 81/200
# 12/12 [==============================] - 4s 308ms/step - loss: 3018.1533
# Epoch 82/200
# 12/12 [==============================] - 4s 305ms/step - loss: 2996.2314
# Epoch 83/200
# 12/12 [==============================] - 4s 305ms/step - loss: 2974.6919
# Epoch 84/200
# 12/12 [==============================] - 4s 311ms/step - loss: 2953.5410
# Epoch 85/200
# 12/12 [==============================] - 4s 306ms/step - loss: 2932.8921
# Epoch 86/200
# 12/12 [==============================] - 3s 290ms/step - loss: 2912.9395
# Epoch 87/200
# 12/12 [==============================] - 4s 346ms/step - loss: 2893.5347
# Epoch 88/200
# 12/12 [==============================] - 4s 363ms/step - loss: 2874.3572
# Epoch 89/200
# 12/12 [==============================] - 4s 333ms/step - loss: 2855.6497
# Epoch 90/200
# 12/12 [==============================] - 4s 326ms/step - loss: 2837.4202
# Epoch 91/200
# 12/12 [==============================] - 4s 312ms/step - loss: 2819.5422
# Epoch 92/200
# 12/12 [==============================] - 4s 316ms/step - loss: 2802.1379
# Epoch 93/200
# 12/12 [==============================] - 4s 311ms/step - loss: 2785.1392
# Epoch 94/200
# 12/12 [==============================] - 4s 315ms/step - loss: 2768.4817
# Epoch 95/200
# 12/12 [==============================] - 4s 318ms/step - loss: 2752.0950
# Epoch 96/200
# 12/12 [==============================] - 4s 324ms/step - loss: 2735.9924
# Epoch 97/200
# 12/12 [==============================] - 4s 322ms/step - loss: 2720.2986
# Epoch 98/200
# 12/12 [==============================] - 4s 318ms/step - loss: 2704.8391
# Epoch 99/200
# 12/12 [==============================] - 4s 316ms/step - loss: 2689.6465
# Epoch 100/200
# 12/12 [==============================] - 4s 322ms/step - loss: 2674.6882
# Epoch 101/200
# 12/12 [==============================] - 4s 323ms/step - loss: 2660.1587
# Epoch 102/200
# 12/12 [==============================] - 4s 322ms/step - loss: 2645.8496
# Epoch 103/200
# 12/12 [==============================] - 4s 318ms/step - loss: 2631.9148
# Epoch 104/200
# 12/12 [==============================] - 4s 329ms/step - loss: 2618.3418
# Epoch 105/200
# 12/12 [==============================] - 4s 316ms/step - loss: 2604.9558
# Epoch 106/200
# 12/12 [==============================] - 4s 322ms/step - loss: 2591.8640
# Epoch 107/200
# 12/12 [==============================] - 4s 319ms/step - loss: 2578.9915
# Epoch 108/200
# 12/12 [==============================] - 4s 309ms/step - loss: 2566.2505
# Epoch 109/200
# 12/12 [==============================] - 4s 327ms/step - loss: 2553.8521
# Epoch 110/200
# 12/12 [==============================] - 4s 325ms/step - loss: 2541.7463
# Epoch 111/200
# 12/12 [==============================] - 4s 328ms/step - loss: 2529.6848
# Epoch 112/200
# 12/12 [==============================] - 4s 324ms/step - loss: 2518.0759
# Epoch 113/200
# 12/12 [==============================] - 4s 322ms/step - loss: 2506.4329
# Epoch 114/200
# 12/12 [==============================] - 4s 327ms/step - loss: 2494.9753
# Epoch 115/200
# 12/12 [==============================] - 4s 335ms/step - loss: 2483.8467
# Epoch 116/200
# 12/12 [==============================] - 4s 309ms/step - loss: 2472.9639
# Epoch 117/200
# 12/12 [==============================] - 4s 329ms/step - loss: 2462.1289
# Epoch 118/200
# 12/12 [==============================] - 4s 333ms/step - loss: 2451.6199
# Epoch 119/200
# 12/12 [==============================] - 4s 369ms/step - loss: 2441.2058
# Epoch 120/200
# 12/12 [==============================] - 4s 370ms/step - loss: 2430.9814
# Epoch 121/200
# 12/12 [==============================] - 4s 351ms/step - loss: 2420.9158
# Epoch 122/200
# 12/12 [==============================] - 4s 327ms/step - loss: 2410.9663
# Epoch 123/200
# 12/12 [==============================] - 4s 355ms/step - loss: 2401.1809
# Epoch 124/200
# 12/12 [==============================] - 4s 351ms/step - loss: 2391.6069
# Epoch 125/200
# 12/12 [==============================] - 4s 334ms/step - loss: 2382.1604
# Epoch 126/200
# 12/12 [==============================] - 4s 317ms/step - loss: 2372.8735
# Epoch 127/200
# 12/12 [==============================] - 4s 299ms/step - loss: 2363.7632
# Epoch 128/200
# 12/12 [==============================] - 4s 302ms/step - loss: 2354.7080
# Epoch 129/200
# 12/12 [==============================] - 4s 307ms/step - loss: 2345.8245
# Epoch 130/200
# 12/12 [==============================] - 4s 300ms/step - loss: 2337.0232
# Epoch 131/200
# 12/12 [==============================] - 4s 307ms/step - loss: 2328.5088
# Epoch 132/200
# 12/12 [==============================] - 4s 306ms/step - loss: 2320.1057
# Epoch 133/200
# 12/12 [==============================] - 4s 308ms/step - loss: 2311.8398
# Epoch 134/200
# 12/12 [==============================] - 4s 306ms/step - loss: 2303.7126
# Epoch 135/200
# 12/12 [==============================] - 4s 304ms/step - loss: 2295.5664
# Epoch 136/200
# 12/12 [==============================] - 4s 303ms/step - loss: 2287.4634
# Epoch 137/200
# 12/12 [==============================] - 4s 304ms/step - loss: 2279.6465
# Epoch 138/200
# 12/12 [==============================] - 4s 307ms/step - loss: 2271.8833
# Epoch 139/200
# 12/12 [==============================] - 4s 308ms/step - loss: 2264.3042
# Epoch 140/200
# 12/12 [==============================] - 4s 315ms/step - loss: 2256.7346
# Epoch 141/200
# 12/12 [==============================] - 4s 307ms/step - loss: 2249.1963
# Epoch 142/200
# 12/12 [==============================] - 4s 309ms/step - loss: 2241.8857
# Epoch 143/200
# 12/12 [==============================] - 3s 287ms/step - loss: 2234.6367
# Epoch 144/200
# 12/12 [==============================] - 4s 298ms/step - loss: 2227.5454
# Epoch 145/200
# 12/12 [==============================] - 4s 301ms/step - loss: 2220.5674
# Epoch 146/200
# 12/12 [==============================] - 4s 306ms/step - loss: 2213.5947
# Epoch 147/200
# 12/12 [==============================] - 4s 301ms/step - loss: 2206.6599
# Epoch 148/200
# 12/12 [==============================] - 4s 300ms/step - loss: 2199.8762
# Epoch 149/200
# 12/12 [==============================] - 4s 307ms/step - loss: 2193.1870
# Epoch 150/200
# 12/12 [==============================] - 4s 306ms/step - loss: 2186.7075
# Epoch 151/200
# 12/12 [==============================] - 4s 306ms/step - loss: 2180.2402
# Epoch 152/200
# 12/12 [==============================] - 4s 338ms/step - loss: 2173.8123
# Epoch 153/200
# 12/12 [==============================] - 4s 321ms/step - loss: 2167.4390
# Epoch 154/200
# 12/12 [==============================] - 5s 398ms/step - loss: 2161.1870
# Epoch 155/200
# 12/12 [==============================] - 4s 367ms/step - loss: 2155.0908
# Epoch 156/200
# 12/12 [==============================] - 4s 356ms/step - loss: 2148.9827
# Epoch 157/200
# 12/12 [==============================] - 4s 325ms/step - loss: 2142.9270
# Epoch 158/200
# 12/12 [==============================] - 4s 348ms/step - loss: 2136.9521
# Epoch 159/200
# 12/12 [==============================] - 4s 327ms/step - loss: 2131.0093
# Epoch 160/200
# 12/12 [==============================] - 4s 342ms/step - loss: 2125.1592
# Epoch 161/200
# 12/12 [==============================] - 4s 326ms/step - loss: 2119.4197
# Epoch 162/200
# 12/12 [==============================] - 4s 320ms/step - loss: 2113.8745
# Epoch 163/200
# 12/12 [==============================] - 4s 315ms/step - loss: 2108.2444
# Epoch 164/200
# 12/12 [==============================] - 4s 325ms/step - loss: 2102.7834
# Epoch 165/200
# 12/12 [==============================] - 4s 339ms/step - loss: 2097.3213
# Epoch 166/200
# 12/12 [==============================] - 4s 314ms/step - loss: 2091.9678
# Epoch 167/200
# 12/12 [==============================] - 4s 313ms/step - loss: 2086.6650
# Epoch 168/200
# 12/12 [==============================] - 4s 326ms/step - loss: 2081.4380
# Epoch 169/200
# 12/12 [==============================] - 4s 321ms/step - loss: 2076.2876
# Epoch 170/200
# 12/12 [==============================] - 4s 316ms/step - loss: 2071.1938
# Epoch 171/200
# 12/12 [==============================] - 4s 321ms/step - loss: 2066.1731
# Epoch 172/200
# 12/12 [==============================] - 4s 328ms/step - loss: 2061.2493
# Epoch 173/200
# 12/12 [==============================] - 4s 313ms/step - loss: 2056.2502
# Epoch 174/200
# 12/12 [==============================] - 4s 321ms/step - loss: 2051.3447
# Epoch 175/200
# 12/12 [==============================] - 4s 319ms/step - loss: 2046.5255
# Epoch 176/200
# 12/12 [==============================] - 4s 324ms/step - loss: 2041.7877
# Epoch 177/200
# 12/12 [==============================] - 4s 317ms/step - loss: 2037.0990
# Epoch 178/200
# 12/12 [==============================] - 4s 315ms/step - loss: 2032.5002
# Epoch 179/200
# 12/12 [==============================] - 4s 320ms/step - loss: 2027.9680
# Epoch 180/200
# 12/12 [==============================] - 4s 326ms/step - loss: 2023.3870
# Epoch 181/200
# 12/12 [==============================] - 4s 339ms/step - loss: 2018.9486
# Epoch 182/200
# 12/12 [==============================] - 4s 335ms/step - loss: 2014.4840
# Epoch 183/200
# 12/12 [==============================] - 4s 319ms/step - loss: 2010.0125
# Epoch 184/200
# 12/12 [==============================] - 4s 329ms/step - loss: 2005.6210
# Epoch 185/200
# 12/12 [==============================] - 4s 341ms/step - loss: 2001.1957
# Epoch 186/200
# 12/12 [==============================] - 4s 327ms/step - loss: 1996.9120
# Epoch 187/200
# 12/12 [==============================] - 4s 322ms/step - loss: 1992.6331
# Epoch 188/200
# 12/12 [==============================] - 4s 316ms/step - loss: 1988.4578
# Epoch 189/200
# 12/12 [==============================] - 4s 313ms/step - loss: 1984.2493
# Epoch 190/200
# 12/12 [==============================] - 4s 320ms/step - loss: 1980.1398
# Epoch 191/200
# 12/12 [==============================] - 4s 319ms/step - loss: 1976.1084
# Epoch 192/200
# 12/12 [==============================] - 4s 318ms/step - loss: 1972.0586
# Epoch 193/200
# 12/12 [==============================] - 4s 329ms/step - loss: 1968.1169
# Epoch 194/200
# 12/12 [==============================] - 4s 319ms/step - loss: 1964.2067
# Epoch 195/200
# 12/12 [==============================] - 4s 314ms/step - loss: 1960.3516
# Epoch 196/200
# 12/12 [==============================] - 4s 319ms/step - loss: 1956.4518
# Epoch 197/200
# 12/12 [==============================] - 4s 317ms/step - loss: 1952.6670
# Epoch 198/200
# 12/12 [==============================] - 4s 323ms/step - loss: 1948.8988
# Epoch 199/200
# 12/12 [==============================] - 4s 318ms/step - loss: 1945.2286
# Epoch 200/200
# 12/12 [==============================] - 4s 323ms/step - loss: 1941.5298

# %% [markdown]
# An additional step when evaluating KGEs: Define a filter so that no negative statements generated by the corruption procedure are actually positives.

# %%
filter = {'test': np.concatenate([X_train, X_test])}

# %% [markdown]
# Evaluate model

# %%
ranks = model.evaluate(X_test,
                       use_filter=filter,
                       corrupt_side='s,o',
                       verbose=True)
# Out:
# 249/249 [==============================] - 47s 188ms/step

# %% [markdown]
# We used the mrr_score (mean reciprocal rank) and hits_at_n_score functions to evaluate the quality of our predictions:

# %%
from ampligraph.evaluation import mr_score, mrr_score, hits_at_n_score

mr = mr_score(ranks)
mrr = mrr_score(ranks)

print("MRR: %.2f" % (mrr))
print("MR: %.2f" % (mr))

hits_10 = hits_at_n_score(ranks, n=10)
print("Hits@10: %.2f" % (hits_10))
hits_3 = hits_at_n_score(ranks, n=3)
print("Hits@3: %.2f" % (hits_3))
hits_1 = hits_at_n_score(ranks, n=1)
print("Hits@1: %.2f" % (hits_1))
# Out:
# MRR: 0.88
# MR: 37.32
# Hits@10: 0.90
# Hits@3: 0.88
# Hits@1: 0.87

# %% [markdown]
# Get embeddings for PTCodes

# %%
ptcs = data.PTCode.unique()
ptc_embeddings = dict(zip(ptcs, model.get_embeddings(ptcs)))

# %% [markdown]
# We use PCA to project the embeddings from the 200 space into 2D space:

# %%
embeddings_2d = PCA(n_components=2).fit_transform(np.array([i for i in ptc_embeddings.values()]))

# %% [markdown]
# Find the ideal k-value

# %%
from sklearn.cluster import KMeans

WCSS = []
for i in range(1, 11):
    km = KMeans(n_clusters=i, n_init=50, max_iter=500, random_state=0,init = 'k-means++')
    km.fit(embeddings_2d )
    WCSS.append(km.inertia_)

# plot
plt.plot(range(1, 11), WCSS, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show() # Based on elbow method, k should be 4.

# %% [markdown]
# We now cluster the teams embeddings on its original 200-dimensional space:

# %%
from ampligraph.discovery import find_clusters

clustering_algorithm = KMeans(n_clusters=4, n_init=50, max_iter=500, random_state=0)
clusters = find_clusters(ptcs, model, clustering_algorithm, mode='e')

print(len(clusters))
print(len(ptcs))
# Out:
# 598
# 598

# %% [markdown]
# Store the clusters for later use

# %%
# Cluster-patient dictionary

results = dict(zip(clusters, ptcs))

with open("clusters_ptc.txt", 'w') as f: 
    for key, value in results.items(): 
        f.write('%s:%s\n' % (key, value))

# %% [markdown]
# Visualization

# %%
plot_df = pd.DataFrame({"ptcs": ptcs, 
                        "embedding1": embeddings_2d[:, 0], 
                        "embedding2": embeddings_2d[:, 1],
                        "cluster": "cluster" + pd.Series(clusters).astype(str)})

# %%
# Plot 2D embeddings
def plot_clusters(hue):
    plt.figure(figsize=(12, 12))
    plt.title("{} embeddings".format(hue).capitalize())
    ax = sns.scatterplot(data=plot_df,
                         x="embedding1", y="embedding2", hue=hue)

# %%
plot_clusters("cluster")
