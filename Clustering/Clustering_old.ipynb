# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

import rdflib
from rdflib import Graph, Literal, Namespace, RDF, URIRef, OWL
from rdflib.extras.external_graph_libs import rdflib_to_networkx_digraph
from rdflib.namespace import DC, FOAF

from owlready2 import *
from owlready2 import get_ontology

from sklearn.model_selection import train_test_split

import networkx as nx
import networkx.algorithms.community as nx_comm

from sklearn.decomposition import PCA
import seaborn as sns
from adjustText import adjust_text
# %matplotlib inline

random.seed(10)
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation

# %% [markdown]
# Loading the altered dataset i.e. with necessary columns

# %%
data = pd.read_excel('opioid_data_merged_min.xlsx')
data = data.dropna()

# %%
data
# Out:
#      WorldwideUniqueCaseIdentification     sex                  Outcome  \
# 0        NL-002147023-NVSC2020NL143475  female  Recovered with sequelae
# 1        NL-002147023-NVSC2020NL143475  female  Recovered with sequelae
# 2        NL-002147023-NVSC2020NL223553  female                Recovered
# 3        NL-002147023-NVSC2020NL223553  female                Recovered
# 4        NL-002147023-NVSC2020NL223553  female                Recovered
# ...                                ...     ...                      ...
# 6192                 NL-TEVA-719924ROM    male                Recovered
# 6193                 NL-TEVA-719924ROM    male                Recovered
# 6194                 NL-TEVA-719924ROM    male                Recovered
# 6195                 NL-TEVA-719924ROM    male                Recovered
# 6196                 NL-TEVA-719924ROM    male                Recovered
#
#        ATCode    PTCode  Frequency     age_group weight_group
# 0     N02AX02  10012218        0.1  (64.0, 90.0]   overweight
# 1     N02AX02  10075611        0.0  (64.0, 90.0]   overweight
# 2     N02AX02  10076493        0.0  (64.0, 90.0]   overweight
# 3     N02AX02  10009839        0.0  (64.0, 90.0]   overweight
# 4     N02AX02  10009839        0.0  (64.0, 90.0]   overweight
# ...       ...       ...        ...           ...          ...
# 6192  N02AA05  10037660        0.0  (64.0, 90.0]       normal
# 6193  N02AA05  10062352        0.0  (64.0, 90.0]       normal
# 6194  N02AA05  10006002        0.0  (64.0, 90.0]       normal
# 6195  N02AA05  10046571        0.0  (64.0, 90.0]       normal
# 6196  N02AA05  10062352        0.0  (64.0, 90.0]       normal
#
# [5406 rows x 8 columns]

# %% [markdown]
# Some transformations

# %%
data['WorldwideUniqueCaseIdentification'] = data.WorldwideUniqueCaseIdentification.astype(str)
data['age_group'] = data.age_group.astype(str)
data['PTCode'] = data.PTCode.astype(str)

# %% [markdown]
# Triple extraction

# %%
triples = []
for _, row in data.iterrows():
        
    # Weight group info
    weight_group = (row['WorldwideUniqueCaseIdentification'], "hasWeightGroup", row['weight_group'])

    # Age group info
    age_group = (row['WorldwideUniqueCaseIdentification'], "hasAgeGroup", row['age_group'])

    # Gender info
    sex = (row['WorldwideUniqueCaseIdentification'], "hasGender", row['sex'])

    #Outcome
    outcome = (row['WorldwideUniqueCaseIdentification'], "hasOutcome", row['Outcome'])

    #Symptom
    symptom = (row['WorldwideUniqueCaseIdentification'], "hasSymptom", row['PTCode'])

    #Drug
    drug = (row['WorldwideUniqueCaseIdentification'], "isGivenDrug", row['ATCode'])

    #Frequency
    frequency = (row['PTCode'], "hasFrequency", row['Frequency'])    
    
    triples.extend((weight_group, age_group, sex, outcome, symptom, drug, frequency))

# %% [markdown]
# This is how they look in a dataframe:

# %%
triples_df = pd.DataFrame(triples, columns=["subject", "predicate", "object"])
triples_df = triples_df.drop_duplicates()
triples_df[(triples_df.subject=="NL-TEVA-719924ROM")]
# Out:
#                  subject       predicate        object
# 37793  NL-TEVA-719924ROM  hasWeightGroup        normal
# 37794  NL-TEVA-719924ROM     hasAgeGroup  (64.0, 90.0]
# 37795  NL-TEVA-719924ROM       hasGender          male
# 37796  NL-TEVA-719924ROM      hasOutcome     Recovered
# 37797  NL-TEVA-719924ROM      hasSymptom      10046571
# 37798  NL-TEVA-719924ROM     isGivenDrug       N02AA05
# 37804  NL-TEVA-719924ROM      hasSymptom      10047700
# 37811  NL-TEVA-719924ROM      hasSymptom      10037660
# 37818  NL-TEVA-719924ROM      hasSymptom      10062352
# 37825  NL-TEVA-719924ROM      hasSymptom      10006002

# %% [markdown]
# Train-test split

# %%
from ampligraph.evaluation import train_test_split_no_unseen

test_size = int(0.2*len(triples))

X_train, X_test = train_test_split_no_unseen(np.array(triples), test_size=test_size)

print('Train set size: ', X_train.shape)
print('Test set size: ', X_test.shape)
# Out:
# Train set size:  (30274, 3)
# Test set size:  (7568, 3)

# %% [markdown]
# We choose ComplEx as our Knowledge Graph Embedding model:

# %%
from ampligraph.latent_features.models import ScoringBasedEmbeddingModel
    
# Initialize a ComplEx neural embedding model: the embedding size is k,
# eta specifies the number of corruptions to generate per each positive,
# scoring_type determines the scoring function of the embedding model.
model = ScoringBasedEmbeddingModel(k=150,
                                   eta=10,
                                   scoring_type='ComplEx')

# %% [markdown]
# Compile model

# %%
import tensorflow as tf

from ampligraph.latent_features.loss_functions import get as get_loss
from ampligraph.latent_features.regularizers import get as get_regularizer

# Optimizer, loss and regularizer definition
optim = tf.keras.optimizers.Adam(learning_rate=1e-3)
loss = get_loss('pairwise', {'margin': 0.5})
regularizer = get_regularizer('LP', {'p': 2, 'lambda': 1e-5})

# Compilation of the model
model.compile(loss=loss,
              optimizer='adam',
              entity_relation_regularizer=regularizer,
              entity_relation_initializer='glorot_uniform')

# %% [markdown]
# Train model

# %%
# Fit the model on training and validation set

history = model.fit(X_train,
          batch_size=int(X_train.shape[0] / 10), # use 1/10 of the training set as batch size
          epochs=200,                    # Number of training epochs
          verbose=True                  # Enable stdout messages
          )
# Out:
# Epoch 1/200
# 12/12 [==============================] - 5s 442ms/step - loss: 13732.2256
# Epoch 2/200
# 12/12 [==============================] - 2s 181ms/step - loss: 13675.6260
# Epoch 3/200
# 12/12 [==============================] - 2s 177ms/step - loss: 13589.0244
# Epoch 4/200
# 12/12 [==============================] - 3s 211ms/step - loss: 13446.5146
# Epoch 5/200
# 12/12 [==============================] - 3s 209ms/step - loss: 13214.4121
# Epoch 6/200
# 12/12 [==============================] - 2s 208ms/step - loss: 12848.5166
# Epoch 7/200
# 12/12 [==============================] - 2s 206ms/step - loss: 12294.3232
# Epoch 8/200
# 12/12 [==============================] - 2s 206ms/step - loss: 11553.4746
# Epoch 9/200
# 12/12 [==============================] - 3s 212ms/step - loss: 10756.3750
# Epoch 10/200
# 12/12 [==============================] - 2s 206ms/step - loss: 10017.9844
# Epoch 11/200
# 12/12 [==============================] - 2s 205ms/step - loss: 9361.7275
# Epoch 12/200
# 12/12 [==============================] - 2s 206ms/step - loss: 8782.9307
# Epoch 13/200
# 12/12 [==============================] - 2s 203ms/step - loss: 8270.6982
# Epoch 14/200
# 12/12 [==============================] - 2s 208ms/step - loss: 7816.4658
# Epoch 15/200
# 12/12 [==============================] - 2s 204ms/step - loss: 7410.0039
# Epoch 16/200
# 12/12 [==============================] - 2s 203ms/step - loss: 7045.3154
# Epoch 17/200
# 12/12 [==============================] - 3s 215ms/step - loss: 6716.5005
# Epoch 18/200
# 12/12 [==============================] - 2s 204ms/step - loss: 6419.5684
# Epoch 19/200
# 12/12 [==============================] - 2s 201ms/step - loss: 6149.3784
# Epoch 20/200
# 12/12 [==============================] - 2s 205ms/step - loss: 5903.8501
# Epoch 21/200
# 12/12 [==============================] - 2s 198ms/step - loss: 5680.0630
# Epoch 22/200
# 12/12 [==============================] - 2s 204ms/step - loss: 5474.5322
# Epoch 23/200
# 12/12 [==============================] - 2s 207ms/step - loss: 5285.9253
# Epoch 24/200
# 12/12 [==============================] - 2s 206ms/step - loss: 5111.0234
# Epoch 25/200
# 12/12 [==============================] - 3s 210ms/step - loss: 4949.4321
# Epoch 26/200
# 12/12 [==============================] - 3s 210ms/step - loss: 4799.0981
# Epoch 27/200
# 12/12 [==============================] - 2s 207ms/step - loss: 4659.3521
# Epoch 28/200
# 12/12 [==============================] - 3s 214ms/step - loss: 4528.8096
# Epoch 29/200
# 12/12 [==============================] - 3s 209ms/step - loss: 4406.7236
# Epoch 30/200
# 12/12 [==============================] - 3s 210ms/step - loss: 4293.0610
# Epoch 31/200
# 12/12 [==============================] - 3s 210ms/step - loss: 4186.1201
# Epoch 32/200
# 12/12 [==============================] - 3s 209ms/step - loss: 4085.6487
# Epoch 33/200
# 12/12 [==============================] - 2s 208ms/step - loss: 3990.7451
# Epoch 34/200
# 12/12 [==============================] - 3s 215ms/step - loss: 3901.3416
# Epoch 35/200
# 12/12 [==============================] - 2s 208ms/step - loss: 3816.8396
# Epoch 36/200
# 12/12 [==============================] - 3s 215ms/step - loss: 3736.8093
# Epoch 37/200
# 12/12 [==============================] - 3s 215ms/step - loss: 3660.9062
# Epoch 38/200
# 12/12 [==============================] - 3s 215ms/step - loss: 3589.2646
# Epoch 39/200
# 12/12 [==============================] - 3s 213ms/step - loss: 3520.8052
# Epoch 40/200
# 12/12 [==============================] - 3s 218ms/step - loss: 3455.3938
# Epoch 41/200
# 12/12 [==============================] - 3s 212ms/step - loss: 3393.6494
# Epoch 42/200
# 12/12 [==============================] - 3s 220ms/step - loss: 3334.5305
# Epoch 43/200
# 12/12 [==============================] - 3s 211ms/step - loss: 3278.0298
# Epoch 44/200
# 12/12 [==============================] - 2s 208ms/step - loss: 3224.2080
# Epoch 45/200
# 12/12 [==============================] - 3s 212ms/step - loss: 3172.7913
# Epoch 46/200
# 12/12 [==============================] - 3s 210ms/step - loss: 3123.4087
# Epoch 47/200
# 12/12 [==============================] - 3s 214ms/step - loss: 3076.0171
# Epoch 48/200
# 12/12 [==============================] - 3s 246ms/step - loss: 3030.5767
# Epoch 49/200
# 12/12 [==============================] - 3s 219ms/step - loss: 2987.1067
# Epoch 50/200
# 12/12 [==============================] - 3s 251ms/step - loss: 2945.0432
# Epoch 51/200
# 12/12 [==============================] - 3s 255ms/step - loss: 2904.8599
# Epoch 52/200
# 12/12 [==============================] - 3s 256ms/step - loss: 2866.2075
# Epoch 53/200
# 12/12 [==============================] - 3s 244ms/step - loss: 2829.2212
# Epoch 54/200
# 12/12 [==============================] - 3s 250ms/step - loss: 2793.3252
# Epoch 55/200
# 12/12 [==============================] - 3s 269ms/step - loss: 2758.6482
# Epoch 56/200
# 12/12 [==============================] - 3s 225ms/step - loss: 2725.1489
# Epoch 57/200
# 12/12 [==============================] - 3s 212ms/step - loss: 2692.8982
# Epoch 58/200
# 12/12 [==============================] - 3s 216ms/step - loss: 2661.9751
# Epoch 59/200
# 12/12 [==============================] - 3s 211ms/step - loss: 2631.9092
# Epoch 60/200
# 12/12 [==============================] - 3s 210ms/step - loss: 2602.8496
# Epoch 61/200
# 12/12 [==============================] - 3s 213ms/step - loss: 2574.6453
# Epoch 62/200
# 12/12 [==============================] - 3s 210ms/step - loss: 2547.4729
# Epoch 63/200
# 12/12 [==============================] - 2s 198ms/step - loss: 2520.9446
# Epoch 64/200
# 12/12 [==============================] - 2s 192ms/step - loss: 2495.3677
# Epoch 65/200
# 12/12 [==============================] - 2s 190ms/step - loss: 2470.6423
# Epoch 66/200
# 12/12 [==============================] - 2s 194ms/step - loss: 2446.4929
# Epoch 67/200
# 12/12 [==============================] - 3s 216ms/step - loss: 2423.1187
# Epoch 68/200
# 12/12 [==============================] - 3s 216ms/step - loss: 2400.1338
# Epoch 69/200
# 12/12 [==============================] - 3s 213ms/step - loss: 2377.9294
# Epoch 70/200
# 12/12 [==============================] - 3s 209ms/step - loss: 2356.5498
# Epoch 71/200
# 12/12 [==============================] - 3s 213ms/step - loss: 2335.7305
# Epoch 72/200
# 12/12 [==============================] - 3s 214ms/step - loss: 2315.2810
# Epoch 73/200
# 12/12 [==============================] - 3s 216ms/step - loss: 2295.5820
# Epoch 74/200
# 12/12 [==============================] - 3s 225ms/step - loss: 2276.3040
# Epoch 75/200
# 12/12 [==============================] - 3s 274ms/step - loss: 2257.6704
# Epoch 76/200
# 12/12 [==============================] - 3s 238ms/step - loss: 2239.5159
# Epoch 77/200
# 12/12 [==============================] - 3s 219ms/step - loss: 2221.8406
# Epoch 78/200
# 12/12 [==============================] - 3s 219ms/step - loss: 2204.6101
# Epoch 79/200
# 12/12 [==============================] - 3s 215ms/step - loss: 2187.7805
# Epoch 80/200
# 12/12 [==============================] - 3s 217ms/step - loss: 2171.3550
# Epoch 81/200
# 12/12 [==============================] - 3s 219ms/step - loss: 2155.2773
# Epoch 82/200
# 12/12 [==============================] - 3s 231ms/step - loss: 2139.7048
# Epoch 83/200
# 12/12 [==============================] - 3s 223ms/step - loss: 2124.3374
# Epoch 84/200
# 12/12 [==============================] - 3s 258ms/step - loss: 2109.3762
# Epoch 85/200
# 12/12 [==============================] - 3s 237ms/step - loss: 2094.6426
# Epoch 86/200
# 12/12 [==============================] - 3s 257ms/step - loss: 2080.2371
# Epoch 87/200
# 12/12 [==============================] - 3s 266ms/step - loss: 2066.2319
# Epoch 88/200
# 12/12 [==============================] - 3s 241ms/step - loss: 2052.8699
# Epoch 89/200
# 12/12 [==============================] - 3s 232ms/step - loss: 2039.6698
# Epoch 90/200
# 12/12 [==============================] - 3s 265ms/step - loss: 2026.6095
# Epoch 91/200
# 12/12 [==============================] - 3s 270ms/step - loss: 2013.8927
# Epoch 92/200
# 12/12 [==============================] - 3s 259ms/step - loss: 2001.5792
# Epoch 93/200
# 12/12 [==============================] - 3s 246ms/step - loss: 1989.3054
# Epoch 94/200
# 12/12 [==============================] - 4s 294ms/step - loss: 1977.2985
# Epoch 95/200
# 12/12 [==============================] - 4s 320ms/step - loss: 1965.6063
# Epoch 96/200
# 12/12 [==============================] - 3s 289ms/step - loss: 1954.2339
# Epoch 97/200
# 12/12 [==============================] - 4s 298ms/step - loss: 1942.9614
# Epoch 98/200
# 12/12 [==============================] - 4s 296ms/step - loss: 1931.9592
# Epoch 99/200
# 12/12 [==============================] - 3s 279ms/step - loss: 1921.1191
# Epoch 100/200
# 12/12 [==============================] - 3s 265ms/step - loss: 1910.6218
# Epoch 101/200
# 12/12 [==============================] - 3s 291ms/step - loss: 1900.3276
# Epoch 102/200
# 12/12 [==============================] - 4s 313ms/step - loss: 1890.2139
# Epoch 103/200
# 12/12 [==============================] - 3s 268ms/step - loss: 1880.2068
# Epoch 104/200
# 12/12 [==============================] - 4s 326ms/step - loss: 1870.4561
# Epoch 105/200
# 12/12 [==============================] - 4s 295ms/step - loss: 1860.9686
# Epoch 106/200
# 12/12 [==============================] - 3s 246ms/step - loss: 1851.5476
# Epoch 107/200
# 12/12 [==============================] - 3s 218ms/step - loss: 1842.4070
# Epoch 108/200
# 12/12 [==============================] - 3s 228ms/step - loss: 1833.3666
# Epoch 109/200
# 12/12 [==============================] - 3s 219ms/step - loss: 1824.4800
# Epoch 110/200
# 12/12 [==============================] - 3s 229ms/step - loss: 1815.6686
# Epoch 111/200
# 12/12 [==============================] - 3s 234ms/step - loss: 1807.1228
# Epoch 112/200
# 12/12 [==============================] - 3s 222ms/step - loss: 1798.7311
# Epoch 113/200
# 12/12 [==============================] - 3s 216ms/step - loss: 1790.3658
# Epoch 114/200
# 12/12 [==============================] - 3s 227ms/step - loss: 1782.2992
# Epoch 115/200
# 12/12 [==============================] - 3s 238ms/step - loss: 1774.3690
# Epoch 116/200
# 12/12 [==============================] - 3s 237ms/step - loss: 1766.5654
# Epoch 117/200
# 12/12 [==============================] - 3s 221ms/step - loss: 1758.9409
# Epoch 118/200
# 12/12 [==============================] - 3s 217ms/step - loss: 1751.3949
# Epoch 119/200
# 12/12 [==============================] - 3s 221ms/step - loss: 1743.9595
# Epoch 120/200
# 12/12 [==============================] - 3s 218ms/step - loss: 1736.7805
# Epoch 121/200
# 12/12 [==============================] - 3s 213ms/step - loss: 1729.5348
# Epoch 122/200
# 12/12 [==============================] - 3s 213ms/step - loss: 1722.3538
# Epoch 123/200
# 12/12 [==============================] - 3s 220ms/step - loss: 1715.4386
# Epoch 124/200
# 12/12 [==============================] - 3s 216ms/step - loss: 1708.6101
# Epoch 125/200
# 12/12 [==============================] - 3s 214ms/step - loss: 1702.0178
# Epoch 126/200
# 12/12 [==============================] - 3s 216ms/step - loss: 1695.3784
# Epoch 127/200
# 12/12 [==============================] - 3s 213ms/step - loss: 1688.8624
# Epoch 128/200
# 12/12 [==============================] - 3s 212ms/step - loss: 1682.4926
# Epoch 129/200
# 12/12 [==============================] - 3s 219ms/step - loss: 1676.1892
# Epoch 130/200
# 12/12 [==============================] - 3s 215ms/step - loss: 1669.9949
# Epoch 131/200
# 12/12 [==============================] - 3s 219ms/step - loss: 1663.8204
# Epoch 132/200
# 12/12 [==============================] - 3s 216ms/step - loss: 1657.6929
# Epoch 133/200
# 12/12 [==============================] - 3s 217ms/step - loss: 1651.7876
# Epoch 134/200
# 12/12 [==============================] - 3s 222ms/step - loss: 1645.9648
# Epoch 135/200
# 12/12 [==============================] - 3s 218ms/step - loss: 1640.2793
# Epoch 136/200
# 12/12 [==============================] - 3s 217ms/step - loss: 1634.4100
# Epoch 137/200
# 12/12 [==============================] - 3s 212ms/step - loss: 1628.7236
# Epoch 138/200
# 12/12 [==============================] - 3s 217ms/step - loss: 1623.1971
# Epoch 139/200
# 12/12 [==============================] - 3s 214ms/step - loss: 1617.7457
# Epoch 140/200
# 12/12 [==============================] - 3s 212ms/step - loss: 1612.4570
# Epoch 141/200
# 12/12 [==============================] - 3s 214ms/step - loss: 1607.1998
# Epoch 142/200
# 12/12 [==============================] - 3s 213ms/step - loss: 1601.9558
# Epoch 143/200
# 12/12 [==============================] - 3s 218ms/step - loss: 1596.8115
# Epoch 144/200
# 12/12 [==============================] - 3s 216ms/step - loss: 1591.7903
# Epoch 145/200
# 12/12 [==============================] - 3s 217ms/step - loss: 1586.6931
# Epoch 146/200
# 12/12 [==============================] - 3s 222ms/step - loss: 1581.8298
# Epoch 147/200
# 12/12 [==============================] - 3s 216ms/step - loss: 1576.9921
# Epoch 148/200
# 12/12 [==============================] - 3s 220ms/step - loss: 1572.1947
# Epoch 149/200
# 12/12 [==============================] - 3s 217ms/step - loss: 1567.5220
# Epoch 150/200
# 12/12 [==============================] - 3s 215ms/step - loss: 1562.8837
# Epoch 151/200
# 12/12 [==============================] - 3s 217ms/step - loss: 1558.3313
# Epoch 152/200
# 12/12 [==============================] - 3s 214ms/step - loss: 1553.7831
# Epoch 153/200
# 12/12 [==============================] - 3s 218ms/step - loss: 1549.3041
# Epoch 154/200
# 12/12 [==============================] - 3s 224ms/step - loss: 1544.9807
# Epoch 155/200
# 12/12 [==============================] - 3s 213ms/step - loss: 1540.6176
# Epoch 156/200
# 12/12 [==============================] - 3s 217ms/step - loss: 1536.2477
# Epoch 157/200
# 12/12 [==============================] - 3s 219ms/step - loss: 1531.9910
# Epoch 158/200
# 12/12 [==============================] - 3s 213ms/step - loss: 1527.7711
# Epoch 159/200
# 12/12 [==============================] - 3s 217ms/step - loss: 1523.5330
# Epoch 160/200
# 12/12 [==============================] - 3s 218ms/step - loss: 1519.3646
# Epoch 161/200
# 12/12 [==============================] - 3s 218ms/step - loss: 1515.2668
# Epoch 162/200
# 12/12 [==============================] - 3s 221ms/step - loss: 1511.2704
# Epoch 163/200
# 12/12 [==============================] - 3s 216ms/step - loss: 1507.2988
# Epoch 164/200
# 12/12 [==============================] - 3s 212ms/step - loss: 1503.3708
# Epoch 165/200
# 12/12 [==============================] - 3s 215ms/step - loss: 1499.5361
# Epoch 166/200
# 12/12 [==============================] - 3s 213ms/step - loss: 1495.7034
# Epoch 167/200
# 12/12 [==============================] - 3s 212ms/step - loss: 1491.9104
# Epoch 168/200
# 12/12 [==============================] - 3s 216ms/step - loss: 1488.1691
# Epoch 169/200
# 12/12 [==============================] - 3s 218ms/step - loss: 1484.4602
# Epoch 170/200
# 12/12 [==============================] - 3s 215ms/step - loss: 1480.7821
# Epoch 171/200
# 12/12 [==============================] - 3s 213ms/step - loss: 1477.2191
# Epoch 172/200
# 12/12 [==============================] - 3s 214ms/step - loss: 1473.7159
# Epoch 173/200
# 12/12 [==============================] - 3s 213ms/step - loss: 1470.2223
# Epoch 174/200
# 12/12 [==============================] - 3s 212ms/step - loss: 1466.7216
# Epoch 175/200
# 12/12 [==============================] - 3s 213ms/step - loss: 1463.3717
# Epoch 176/200
# 12/12 [==============================] - 3s 217ms/step - loss: 1459.9661
# Epoch 177/200
# 12/12 [==============================] - 3s 213ms/step - loss: 1456.6791
# Epoch 178/200
# 12/12 [==============================] - 3s 214ms/step - loss: 1453.3398
# Epoch 179/200
# 12/12 [==============================] - 3s 216ms/step - loss: 1450.0530
# Epoch 180/200
# 12/12 [==============================] - 3s 214ms/step - loss: 1446.8556
# Epoch 181/200
# 12/12 [==============================] - 3s 214ms/step - loss: 1443.6929
# Epoch 182/200
# 12/12 [==============================] - 3s 212ms/step - loss: 1440.4124
# Epoch 183/200
# 12/12 [==============================] - 3s 217ms/step - loss: 1437.3156
# Epoch 184/200
# 12/12 [==============================] - 3s 213ms/step - loss: 1434.2051
# Epoch 185/200
# 12/12 [==============================] - 3s 213ms/step - loss: 1431.0726
# Epoch 186/200
# 12/12 [==============================] - 3s 215ms/step - loss: 1428.0725
# Epoch 187/200
# 12/12 [==============================] - 3s 212ms/step - loss: 1425.0648
# Epoch 188/200
# 12/12 [==============================] - 3s 215ms/step - loss: 1422.1235
# Epoch 189/200
# 12/12 [==============================] - 3s 214ms/step - loss: 1419.2180
# Epoch 190/200
# 12/12 [==============================] - 3s 218ms/step - loss: 1416.2770
# Epoch 191/200
# 12/12 [==============================] - 3s 211ms/step - loss: 1413.4409
# Epoch 192/200
# 12/12 [==============================] - 3s 217ms/step - loss: 1410.6063
# Epoch 193/200
# 12/12 [==============================] - 3s 247ms/step - loss: 1407.7240
# Epoch 194/200
# 12/12 [==============================] - 3s 236ms/step - loss: 1404.8707
# Epoch 195/200
# 12/12 [==============================] - 3s 241ms/step - loss: 1402.1650
# Epoch 196/200
# 12/12 [==============================] - 3s 262ms/step - loss: 1399.4357
# Epoch 197/200
# 12/12 [==============================] - 3s 221ms/step - loss: 1396.7255
# Epoch 198/200
# 12/12 [==============================] - 3s 212ms/step - loss: 1394.0654
# Epoch 199/200
# 12/12 [==============================] - 3s 211ms/step - loss: 1391.4833
# Epoch 200/200
# 12/12 [==============================] - 3s 258ms/step - loss: 1388.8413

# %% [markdown]
# An additional step when evaluating KGEs: Define a filter so that no negative statements generated by the corruption procedure are actually positives.

# %%
filter = {'test': np.concatenate([X_train, X_test])}

# %% [markdown]
# Evaluate model

# %%
ranks = model.evaluate(X_test,
                       use_filter=filter,
                       corrupt_side='s,o',
                       verbose=True)
# Out:
# 238/238 [==============================] - 20s 83ms/step

# %% [markdown]
# We used the mrr_score (mean reciprocal rank) and hits_at_n_score functions to evaluate the quality of our predictions:

# %%
from ampligraph.evaluation import mr_score, mrr_score, hits_at_n_score

mr = mr_score(ranks)
mrr = mrr_score(ranks)

print("MRR: %.2f" % (mrr))
print("MR: %.2f" % (mr))

hits_10 = hits_at_n_score(ranks, n=10)
print("Hits@10: %.2f" % (hits_10))
hits_3 = hits_at_n_score(ranks, n=3)
print("Hits@3: %.2f" % (hits_3))
hits_1 = hits_at_n_score(ranks, n=1)
print("Hits@1: %.2f" % (hits_1))
# Out:
# MRR: 0.86
# MR: 50.42
# Hits@10: 0.87
# Hits@3: 0.86
# Hits@1: 0.86

# %% [markdown]
# Get embedings for all patients

# %%
patients = data.WorldwideUniqueCaseIdentification.unique()
patient_embeddings = dict(zip(patients, model.get_embeddings(patients)))

# %% [markdown]
# We use PCA to project the embeddings from the 200 space into 2D space:

# %%
embeddings_2d = PCA(n_components=2).fit_transform(np.array([i for i in patient_embeddings.values()]))

# %% [markdown]
# Find the ideal k-value

# %%
from sklearn.cluster import KMeans

WCSS = []
for i in range(1, 11):
    km = KMeans(n_clusters=i, n_init=50, max_iter=500, random_state=0,init = 'k-means++')
    km.fit(embeddings_2d )
    WCSS.append(km.inertia_)

# plot
plt.plot(range(1, 11), WCSS, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show() # Based on elbow method, k should be 3.

# %% [markdown]
# We now cluster the teams embeddings on its original 200-dimensional space:

# %%
from ampligraph.discovery import find_clusters

clustering_algorithm = KMeans(n_clusters=3, n_init=50, max_iter=500, random_state=0)
clusters = find_clusters(patients, model, clustering_algorithm, mode='e')

print(len(clusters))
print(len(patients))
# Out:
# 1352
# 1352

# %% [markdown]
# Store the clusters for later use

# %%
# Cluster-patient dictionary

results = dict(zip(clusters, patients))

with open("clusters.txt", 'w') as f: 
    for key, value in results.items(): 
        f.write('%s:%s\n' % (key, value))

# %% [markdown]
# Visualization

# %%
plot_df = pd.DataFrame({"patients": patients, 
                        "embedding1": embeddings_2d[:, 0], 
                        "embedding2": embeddings_2d[:, 1],
                        "cluster": "cluster" + pd.Series(clusters).astype(str)})

# %%
# Plot 2D embeddings
def plot_clusters(hue):
    plt.figure(figsize=(12, 12))
    plt.title("{} embeddings".format(hue).capitalize())
    ax = sns.scatterplot(data=plot_df,
                         x="embedding1", y="embedding2", hue=hue)

# %%
plot_clusters("cluster")
